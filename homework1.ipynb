# %%
import pandas as pd

# %%
# 1
odev = pd.read_csv("Chocolate Sales.csv")  
odev
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# ...

# %%
# dataframe'in son birkaç satırını gösterir.
# 2
odev.tail(8)
# Out:
#              Sales Person    Country              Product       Date   Amount  \
# 1086  Dennison Crosswaite     Canada  Organic Choco Syrup  28-Jan-22  $8,491
# 1087       Beverie Moffet      India         Almond Choco  24-May-22  $3,066
# 1088          Brien Boise  Australia  Peanut Butter Cubes  19-Aug-22    $301
# 1089     Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22  $4,410
# 1090       Jehu Rudeforth        USA           White Choc  07-Jun-22  $6,559
# 1091         Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22    $574
# 1092       Dotty Strutley      India              Eclairs  28-Jul-22  $2,086
# 1093     Karlen McCaffrey      India       70% Dark Bites  23-May-22  $5,075
#
#       Boxes Shipped
# 1086             75
# 1087             96
# 1088            205
# 1089            323
# 1090            119
# 1091            217
# 1092            384
# 1093            344

# %%
# sayısal verilerin temel istatistiksel özetini sağlar
# 3
odev.describe()
# Out:
#        Boxes Shipped
# count    1094.000000
# mean      161.797989
# std       121.544145
# min         1.000000
# 25%        70.000000
# 50%       135.000000
# 75%       228.750000
# max       709.000000

# %%
# verileri gruplandırmak için kullanılır
# 4
odev.groupby('Boxes Shipped').sum()
# Out:
#                                                     Sales Person  \
# Boxes Shipped
# 1                                                   Barr Faughny
# 2                   Mallorie WaberMallorie WaberKarlen McCaffrey
# 3                         Dotty StrutleyKelci WalkdenVan Tuxwell
# 4              Van TuxwellMarney O'BreenGigi BohlingMadelene ...
# 5                      Andria KimptonGunar CockshootHusein Augar
# ...                                                          ...
# 591                                                   Oby Sorrel
# 597                                             Karlen McCaffrey
# 614                                               Marney O'Breen
# 708                                             Karlen McCaffrey
# 709                                                  Van Tuxwell
#
#                                          Country  \
# Boxes Shipped
# 1                                         Canada
# 2                                     UKIndiaUSA
# ...

# %%
# verileri belirli bi sütuna göre sıralar
# 5
odev.sort_values(by='Sales Person')
# Out:
#         Sales Person      Country       Date    Amount  Boxes Shipped
# 465   Andria Kimpton          USA  23-May-22   $2,366               5
# 674   Andria Kimpton           UK  07-Jun-22   $7,924             275
# 34    Andria Kimpton       Canada  11-May-22   $2,163              70
# 36    Andria Kimpton           UK  24-Aug-22   $2,653             314
# 1063  Andria Kimpton       Canada  16-Feb-22   $1,127             319
# ...              ...          ...        ...       ...            ...
# 387   Wilone O'Kielt  New Zealand  11-Jul-22   $3,724             234
# 829   Wilone O'Kielt        India  13-Jan-22   $4,179             276
# 390   Wilone O'Kielt  New Zealand  15-Mar-22   $9,198             144
# 921   Wilone O'Kielt        India  04-Aug-22  $12,026             262
# 281   Wilone O'Kielt  New Zealand  19-Aug-22  $11,662             242
#
# [1094 rows x 5 columns]

# %%
# Dataframe veya seriler üzerinde bir fonksiyon uygulamak için kullnılır.
# 6
odev['test']=odev['Boxes Shipped'].apply(lambda x:x*3)
odev
# Out:
#           Sales Person    Country       Date    Amount  Boxes Shipped  test
# 0       Jehu Rudeforth         UK  04-Jan-22   $5,320             180   540
# 1          Van Tuxwell      India  01-Aug-22   $7,896              94   282
# 2         Gigi Bohling      India  07-Jul-22   $4,501              91   273
# 3         Jan Morforth  Australia  27-Apr-22  $12,726             342  1026
# 4       Jehu Rudeforth         UK  24-Feb-22  $13,685             184   552
# ...                ...        ...        ...       ...            ...   ...
# 1089  Karlen McCaffrey  Australia  17-May-22   $4,410             323   969
# 1090    Jehu Rudeforth        USA  07-Jun-22   $6,559             119   357
# 1091      Ches Bonnell     Canada  26-Jul-22     $574             217   651
# 1092    Dotty Strutley      India  28-Jul-22   $2,086             384  1152
# 1093  Karlen McCaffrey      India  23-May-22   $5,075             344  1032
#
# [1094 rows x 6 columns]

# %%
# bir veya birden fazla sütunu Dateframde'in indeks sütunu olarak ayarlamak için kullanılır
# 7
odev.set_index('Sales Person', inplace=True)
odev
# Out:
#                     Country       Date    Amount  Boxes Shipped  test
# Sales Person
# Jehu Rudeforth           UK  04-Jan-22   $5,320             180   540
# Van Tuxwell           India  01-Aug-22   $7,896              94   282
# Gigi Bohling          India  07-Jul-22   $4,501              91   273
# Jan Morforth      Australia  27-Apr-22  $12,726             342  1026
# Jehu Rudeforth           UK  24-Feb-22  $13,685             184   552
# ...                     ...        ...       ...            ...   ...
# Karlen McCaffrey  Australia  17-May-22   $4,410             323   969
# Jehu Rudeforth          USA  07-Jun-22   $6,559             119   357
# Ches Bonnell         Canada  26-Jul-22     $574             217   651
# Dotty Strutley        India  28-Jul-22   $2,086             384  1152
# Karlen McCaffrey      India  23-May-22   $5,075             344  1032
#
# [1094 rows x 5 columns]

# %%
# Dateframe'in indeksini sıfırlar ve eski indeks sütununu veri olarak ekler
# 8
odev.reset_index(inplace=True)
odev
# Out:
#       index      Sales Person    Country       Date    Amount  Boxes Shipped  \
# 0         0    Jehu Rudeforth         UK  04-Jan-22   $5,320             180
# 1         1       Van Tuxwell      India  01-Aug-22   $7,896              94
# 2         2      Gigi Bohling      India  07-Jul-22   $4,501              91
# 3         3      Jan Morforth  Australia  27-Apr-22  $12,726             342
# 4         4    Jehu Rudeforth         UK  24-Feb-22  $13,685             184
# ...     ...               ...        ...        ...       ...            ...
# 1089   1089  Karlen McCaffrey  Australia  17-May-22   $4,410             323
# 1090   1090    Jehu Rudeforth        USA  07-Jun-22   $6,559             119
# 1091   1091      Ches Bonnell     Canada  26-Jul-22     $574             217
# 1092   1092    Dotty Strutley      India  28-Jul-22   $2,086             384
# 1093   1093  Karlen McCaffrey      India  23-May-22   $5,075             344
#
#       test
# 0      540
# 1      282
# ...

# %%
# bir sütundaki benzersiz değerleri döndürür
# 9
unique_values = odev['Boxes Shipped'].unique()
odev
# Out:
#       index      Sales Person    Country       Date    Amount  Boxes Shipped  \
# 0         0    Jehu Rudeforth         UK  04-Jan-22   $5,320             180
# 1         1       Van Tuxwell      India  01-Aug-22   $7,896              94
# 2         2      Gigi Bohling      India  07-Jul-22   $4,501              91
# 3         3      Jan Morforth  Australia  27-Apr-22  $12,726             342
# 4         4    Jehu Rudeforth         UK  24-Feb-22  $13,685             184
# ...     ...               ...        ...        ...       ...            ...
# 1089   1089  Karlen McCaffrey  Australia  17-May-22   $4,410             323
# 1090   1090    Jehu Rudeforth        USA  07-Jun-22   $6,559             119
# 1091   1091      Ches Bonnell     Canada  26-Jul-22     $574             217
# 1092   1092    Dotty Strutley      India  28-Jul-22   $2,086             384
# 1093   1093  Karlen McCaffrey      India  23-May-22   $5,075             344
#
#       test
# 0      540
# 1      282
# ...

# %%
# bir sütundaki her birbenzersiz değer
# 10
value_counts=odev['Sales Person'].value_counts()
value_counts
# Out:
# Sales Person
# Kelci Walkden          54
# Brien Boise            53
# Van Tuxwell            51
# Beverie Moffet         50
# Oby Sorrel             49
# Dennison Crosswaite    49
# Ches Bonnell           48
# Gigi Bohling           47
# Karlen McCaffrey       47
# Curtice Advani         46
# Madelene Upcott        45
# Kaine Padly            45
# Marney O'Breen         45
# Jehu Rudeforth         43
# Roddy Speechley        43
# Gunar Cockshoot        43
# Barr Faughny           43
# Mallorie Waber         41
# Jan Morforth           39
# Andria Kimpton         39
# Husein Augar           38
# Dotty Strutley         36
# Rafaelita Blaksland    34
# Wilone O'Kielt         34
# Camilla Castle         32
# Name: count, dtype: int64
